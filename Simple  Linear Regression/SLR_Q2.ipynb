# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\Excelr assignments\Simple  Linear Regression\data\Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = df['YearsExperience']
y = df['Salary']

# %%
x,y
# Out:
# (0      1.1
#  1      1.3
#  2      1.5
#  3      2.0
#  4      2.2
#  5      2.9
#  6      3.0
#  7      3.2
#  8      3.2
#  9      3.7
#  10     3.9
#  11     4.0
#  12     4.0
#  13     4.1
#  14     4.5
#  15     4.9
#  16     5.1
#  17     5.3
#  18     5.9
#  19     6.0
#  20     6.8
#  21     7.1
#  22     7.9
#  23     8.2
#  24     8.7
#  25     9.0
#  26     9.5
#  27     9.6
#  28    10.3
#  29    10.5
#  Name: YearsExperience, dtype: float64,
#  0      39343.0
#  1      46205.0
#  2      37731.0
#  3      43525.0
#  4      39891.0
#  5      56642.0
#  6      60150.0
#  7      54445.0
#  8      64445.0
#  9      57189.0
#  10     63218.0
#  11     55794.0
#  12     56957.0
#  13     57081.0
#  14     61111.0
#  15     67938.0
#  16     66029.0
#  17     83088.0
#  18     81363.0
#  19     93940.0
#  20     91738.0
#  21     98273.0
#  22    101302.0
#  23    113812.0
#  24    109431.0
#  25    105582.0
#  26    116969.0
#  27    112635.0
#  28    122391.0
# ...

# %%
sns.pairplot(df, kind='reg')
plt.show()

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
corr = np.corrcoef(x, y)
print(corr)
# Out:
# [[1.         0.97824162]
#  [0.97824162 1.        ]]

# %%
model1 = sm.OLS(x_rec,y).fit()
pred1 =model1.predict(x_rec)
pred1
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared (uncentered):                   0.371
# Model:                            OLS   Adj. R-squared (uncentered):              0.350
# Method:                 Least Squares   F-statistic:                              17.12
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    0.000275
# Time:                        00:22:17   Log-Likelihood:                         -3.0683
# No. Observations:                  30   AIC:                                      8.137
# Df Residuals:                      29   BIC:                                      9.538
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_rec = np.reciprocal(x)
x_rec
# Out:
# 0     0.909091
# 1     0.769231
# 2     0.666667
# 3     0.500000
# 4     0.454545
# 5     0.344828
# 6     0.333333
# 7     0.312500
# 8     0.312500
# 9     0.270270
# 10    0.256410
# 11    0.250000
# 12    0.250000
# 13    0.243902
# 14    0.222222
# 15    0.204082
# 16    0.196078
# 17    0.188679
# 18    0.169492
# 19    0.166667
# 20    0.147059
# 21    0.140845
# 22    0.126582
# 23    0.121951
# 24    0.114943
# 25    0.111111
# 26    0.105263
# 27    0.104167
# 28    0.097087
# 29    0.095238
# Name: YearsExperience, dtype: float64

# %%
model2 =sm.OLS(x,y).fit()
pred2= model2.predict()
print(pred2)
model2.summary()
# Out:
# [2.88827099 3.39202809 2.76992992 3.19528238 2.92850108 4.15823515
#  4.41576646 3.99694772 4.73107348 4.19839183 4.64099625 4.09598128
#  4.18136011 4.19046327 4.48631595 4.98750361 4.847359   6.09970414
#  5.97306745 6.89637742 6.73472292 7.21447411 7.4368408  8.35523213
#  8.03361164 7.75104663 8.58699564 8.26882553 8.98503863 8.9469375 ]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        YearsExperience   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              1048.
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    2.56e-24
# Time:                        00:25:21   Log-Likelihood:                         -42.105
# No. Observations:                  30   AIC:                                      86.21
# ...

# %%
x_log = np.log(df['YearsExperience'])
model3 = sm.OLS(y, x_log).fit()
pred3 = model3.predict(x_log)
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              1338.
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    8.06e-26
# Time:                        00:38:12   Log-Likelihood:                         -323.70
# No. Observations:                  30   AIC:                                      649.4
# Df Residuals:                      29   BIC:                                      650.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y_log = np.log(df['Salary'])
model4 = sm.OLS(y_log, x).fit()
pred4 = model4.predict(x)
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.809
# Model:                            OLS   Adj. R-squared (uncentered):              0.802
# Method:                 Least Squares   F-statistic:                              122.8
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    6.09e-12
# Time:                        00:40:05   Log-Likelihood:                         -90.160
# No. Observations:                  30   AIC:                                      182.3
# Df Residuals:                      29   BIC:                                      183.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model5 = sm.OLS(y_log, x_log).fit()
pred5 = model5.predict(x_log)
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.878
# Model:                            OLS   Adj. R-squared (uncentered):              0.874
# Method:                 Least Squares   F-statistic:                              209.1
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    8.60e-15
# Time:                        00:41:13   Log-Likelihood:                         -83.410
# No. Observations:                  30   AIC:                                      168.8
# Df Residuals:                      29   BIC:                                      170.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x_sqrt = np.sqrt(df['YearsExperience'])
model6 = sm.OLS(y, x_sqrt).fit()
pred6 = model6.predict(x_sqrt)
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.989
# Model:                            OLS   Adj. R-squared (uncentered):              0.989
# Method:                 Least Squares   F-statistic:                              2697.
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    3.62e-30
# Time:                        00:41:52   Log-Likelihood:                         -313.35
# No. Observations:                  30   AIC:                                      628.7
# Df Residuals:                      29   BIC:                                      630.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y_sqrt = np.sqrt(df['Salary'])
model7 = sm.OLS(y_sqrt, x).fit()
pred17 = model7.predict(x)
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.906
# Model:                            OLS   Adj. R-squared (uncentered):              0.902
# Method:                 Least Squares   F-statistic:                              278.1
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    2.12e-16
# Time:                        00:42:31   Log-Likelihood:                         -175.75
# No. Observations:                  30   AIC:                                      353.5
# Df Residuals:                      29   BIC:                                      354.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model8 = sm.OLS(y_sqrt, x_sqrt).fit()
pred8 = model8.predict(x_sqrt)
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              2338.
# Date:                Tue, 06 Dec 2022   Prob (F-statistic):                    2.81e-29
# Time:                        00:43:07   Log-Likelihood:                         -145.12
# No. Observations:                  30   AIC:                                      292.2
# Df Residuals:                      29   BIC:                                      293.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# We will use model6 as it has the best R square value 98.9
